# %%
#setup libraries
import numpy as np
import pandas as pd
import os, re, glob, sys
from skimage import io, filters, util, segmentation, morphology, measure, restoration, exposure
import matplotlib.pyplot as plt
#import imageio
from cellpose import models, plot
from pystackreg import StackReg
from scipy import stats, spatial
from PIL import Image, ImageSequence
import tifffile

# %%
pipeline_name = "CK" #cellpose and KIT tracking
ch1_name = 'NR'
ch2_name = 'CC'
data_path = '/home/exacloud/gscratch/HeiserLab/images/'
#data_path = '/Users/dane/Documents/CellTrackingProjects/AU565/images/'
plateID = 'AU02001'
#plateID = sys.argv[1]
well_index = 1
#well_index = int(sys.argv[2])

output_path = os.path.join(data_path+plateID,"Analysis",pipeline_name,"intermediate_files/")
transformation_path = os.path.join(output_path,"transformations")
tracking_path = os.path.join(output_path,'tracking/')

#Only use subdirectories within the selected well
well_directory = sorted(glob.glob(os.path.join(data_path+plateID,"[A-Z][1-9]")))[well_index-1]
well = re.findall("[A-Z][1-9]$",well_directory)[0]
subdirectories = sorted(glob.glob(os.path.join(well_directory,"field_[1-9]")))[0:1]

# %% [markdown]
# #### Register the image stacks
# If there is a registered red channel stack skip this step, otherwise:
# Load the red, green and phase images
# Delete images from any time slice that does not have a complete set of images
# Rescale the fluorescent images from 12 to 8 bits
# Calculate the transformations needed to register the red stack, correcting the translation only
# Store the registration transformations
# Use the transformations to register all three stacks
# Save the registered stacks as 16 bit images
#
# TODO: See if it's possible to not rescale the images

# %%
flourescent_scaler = 255/4095 #rescale from 12 to 8 bits

for subdir in subdirectories:
    field = re.findall("field_[1-9]",subdir)[0]
    field_num = re.findall("[0-9]", field)[0]
    reg_filename = os.path.join(output_path,plateID+"_R_"+well+"_"+field_num+"_reg_stack.tif")
    # Only process the field-level image files if there is no registered stack
    if not os.path.exists(reg_filename):
        print("registering R stack in "+subdir)
        #load and prepare red, green and phase channels. Scale for 8 bits but these are uint16 data types
        r_data_paths = glob.glob(os.path.join(subdir,"*_R_*m.tif"))
        r_time_slices = set()
        for data_paths in r_data_paths:
            r_time_slices.add(re.findall("..d..h..m", data_paths)[0])
        g_data_paths = glob.glob(os.path.join(subdir,"*_G_*m.tif"))
        g_time_slices = set()
        for data_paths in g_data_paths:
            g_time_slices.add(re.findall("..d..h..m", data_paths)[0])
        p_data_paths = glob.glob(os.path.join(subdir,"*_P_*m.tif"))
        p_time_slices = set()
        for data_paths in p_data_paths:
            p_time_slices.add(re.findall("..d..h..m", data_paths)[0])
        complete_time_slices = r_time_slices & g_time_slices & p_time_slices
        r_data_paths_c = []
        g_data_paths_c = []
        p_data_paths_c = []
        for time_slice in complete_time_slices:
            r_data_paths_c.append(os.path.join(data_path+plateID,well,field,plateID+"_R_"+well+"_"+field_num+"_"+time_slice+".tif"))
            g_data_paths_c.append(os.path.join(data_path+plateID,well,field,plateID+"_G_"+well+"_"+field_num+"_"+time_slice+".tif"))
            p_data_paths_c.append(os.path.join(data_path+plateID,well,field,plateID+"_P_"+well+"_"+field_num+"_"+time_slice+".tif"))
        img_r_ic = io.imread_collection(r_data_paths_c) # 3 dimensions : frames x width x height
        img_rs = np.stack(img_r_ic)*flourescent_scaler

        img_g_ic = io.imread_collection(g_data_paths_c) # 3 dimensions : frames x width x height
        img_gs = np.stack(img_g_ic)*flourescent_scaler

        img_p_ic = io.imread_collection(p_data_paths_c) # 3 dimensions : frames x width x height
        img_ps = np.stack(img_p_ic)
        
        #register the R stack using transformation
        sr = StackReg(StackReg.TRANSLATION)
        # register each frame to the previous (already registered) one
        tmats = sr.register_stack(img_rs, reference='previous')
        if not os.path.exists(transformation_path):
            os.makedirs(transformation_path)
        np.save(os.path.join(transformation_path,plateID+"_"+well+"_"+field+"_transformation_matrices.npy"), tmats)
        
        # transform stack using the tmats loaded from file
        img_rs_reg = sr.transform_stack(img_rs, tmats = tmats)
        img_gs_reg = sr.transform_stack(img_gs, tmats = tmats)
        img_ps_reg = sr.transform_stack(img_ps, tmats = tmats)

        img_c = np.stack([img_rs.astype('B'), img_gs.astype('B'), img_ps.astype('B')], axis = -1) 
 #       img_c_reg = np.stack((img_rs_reg.astype(np.int16), img_ps_reg.astype(np.int16)), axis = -1) 
#creates 21k files with (21, 1040, 1408, 2) shape
        img_c_reg = np.stack((img_rs_reg.astype(np.int16), img_ps_reg.astype(np.int16)), axis = 1) #create tcxy 


        if not os.path.exists(output_path):
            os.makedirs(output_path)

        print("saving "+reg_filename)
        io.imsave(reg_filename, img_rs_reg.astype(np.int16), plugin='tifffile', check_contrast=False)
        print("saving "+reg_filename.replace("_R_","_G_"))
        io.imsave(reg_filename.replace("_R_","_G_"), img_gs_reg.astype(np.int16), plugin='tifffile', check_contrast=False)
        print("saving "+reg_filename.replace("_R_","_P_"))
        io.imsave(reg_filename.replace("_R_","_P_"), img_ps_reg.astype(np.int16), plugin='tifffile', check_contrast=False)
        print("saving "+reg_filename.replace("_R_","_C_"))
        io.imsave(reg_filename.replace("_R_","_C_"), img_c_reg, plugin='tifffile', check_contrast=False)

# %% [markdown]
# #### Segment the phase  images using cellpose
# If mask files already exist, skip this step, otherwise:
# Load the registered phase images
# Segment each image and only keep masks greater than a selected area
# Save the mask files as an image sequence
# For compatibility with the tracking method, save the masks and the phase images as indivdual files

# %%
diameter = 16
n_diameter = 13
flow_threshold = 0
n_flow_threshold = .7
mask_threshold=0
n_mask_threshold=0
min_size=75
n_min_size=75
resample = True

#call cellpose on each image to segment the phase cytoplasm and nuclei
# DEFINE CELLPOSE MODELs
model = models.Cellpose(gpu=True, model_type='cyto')
n_model = models.Cellpose(gpu=True, model_type='nuclei')

# define CHANNELS to run segementation on
# grayscale=0, R=1, G=2, B=3
# channels = [cytoplasm, nucleus]
# if NUCLEUS channel does not exist, set the second channel to 0
# will use channel R = 1 as nuclear channel only
cy_channels = [2,1]
n_channels = [1,0]

for subdir in subdirectories:
    results = [] #collect results for one field in the well
    field = re.findall("field_[1-9]",subdir)[0]
    field_num = re.findall("[0-9]", field)[0]
    reg_filename = os.path.join(output_path,plateID+"_R_"+well+"_"+field_num+"_reg_stack.tif")
    reg_filename = os.path.join(output_path,plateID+"_C_"+well+"_"+field_num+"_reg_stack.tif")
    cy_mask_filename = reg_filename.replace("_reg_stack.tif", "_masks_stack.png")
    tracking_path = os.path.join(output_path,'tracking/')
    if not os.path.exists(tracking_path+well+"/"+field+"/masks/"):
            os.makedirs(tracking_path+well+"/"+field+"/masks/")
    if not os.path.exists(tracking_path+well+"/"+field+"/nmasks/"):
            os.makedirs(tracking_path+well+"/"+field+"/nmasks/")
    if not os.path.exists(tracking_path+well+"/"+field+"/reg"):
            os.makedirs(tracking_path+well+"/"+field+"/reg")
    if not os.path.exists(tracking_path+well+"/"+field+"/results"):
            os.makedirs(tracking_path+well+"/"+field+"/results")
    if not os.path.exists(tracking_path+well+"/"+field+"/filtered_masks"):
            os.makedirs(tracking_path+well+"/"+field+"/filtered_masks")

    if not os.path.exists(cy_mask_filename): #Only segment if no mask file
        img_rs_reg = io.imread(reg_filename)
                         
        cy_mask_images = []
        n_mask_images = []
        for i, image in enumerate(img_rs_reg):
            print("processing "+reg_filename+" index "+str(i))
            #Segment using the nuclear signal in the red channel
            #background = restoration.rolling_ball(image, radius=50)
            #image_bc = exposure.adjust_log(image-background, gain=1, inv=False)
            #image_rf = filters.median(image_bc, morphology.disk(1))

            # create masks with cellpose 
            cy_masks, flows, styles, diams = model.eval(image,
                                             diameter=diameter,
                                             flow_threshold=flow_threshold,
                                             mask_threshold=mask_threshold,
                                             channels=cy_channels,
                                             min_size=min_size,
                                             resample = resample)
       
            #Save mask image
            cy_mask_images.append(cy_masks)
            
             # create nuclear masks with cellpose 
            n_masks, flows, styles, diams = n_model.eval(image,
                                             diameter=n_diameter,
                                             flow_threshold=n_flow_threshold,
                                             mask_threshold=n_mask_threshold,
                                             channels=n_channels,
                                             min_size=n_min_size,
                                             resample = resample)
       
            #Save mask image
            n_mask_images.append(n_masks)
            
        tifffile.imwrite(cy_mask_filename, np.array(cy_mask_images), imagej=True)
        tifffile.imwrite(cy_mask_filename.replace('masks', 'nmasks'), np.array(n_mask_images), imagej=True)

        # Open the cyto mask stack:
        im = Image.open(cy_mask_filename)
 
        # create an index variable:
        i =0
        app = []
 
        # iterate over the cyto mask stack and save each frame to disk:
        for fr in ImageSequence.Iterator(im):
            app.append(fr)
            fr.save(tracking_path+well+"/"+field+"/masks/"+"mask%03.d.tif"%i)
            i = i + 1
            
         # Open the nuclear mask stack:
        im = Image.open(cy_mask_filename.replace('masks', 'nmasks'))
 
        # create an index variable:
        i =0
        app = []
 
        # iterate over the nuclear mask stack and save each frame to disk:
        for fr in ImageSequence.Iterator(im):
            app.append(fr)
            fr.save(tracking_path+well+"/"+field+"/nmasks/"+"nmask%03.d.tif"%i)
            i = i + 1
        
#        # Open the registered intensity stack: use the phase images
        im = Image.open(reg_filename.replace("_C_", "_P_"))
 
        # create an index variable:
        i = 0
        app = []
 
        # iterate over the registered phase stack and save each frame to disk:
        for fr in ImageSequence.Iterator(im):
            app.append(fr)
            fr.save(tracking_path+well+"/"+field+"/reg/"+"t%03.d.tif"%i)
            i = i + 1
# Out:
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 0
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 1
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 2
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 3
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 4
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 5
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 6
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 7
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 8
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 9
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 10
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 11
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 12
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 13
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 14
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 15
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 16
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 17
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 18
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 19
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 20
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 21
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 22
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 23
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 24
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 25
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 26
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 27
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 28
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 29
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 30
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 31
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 32
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 33
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 34
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 35
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 36
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 37
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 38
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 39
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 40
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 41
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 42
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 43
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 44
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 45
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 46
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 47
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 48
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 49
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 50
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 51
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 52
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 53
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 54
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 55
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 56
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 57
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 58
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 59
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 60
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 61
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 62
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 63
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 64
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 65
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 66
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 67
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 68
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 69
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 70
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 71
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 72
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 73
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 74
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 75
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 76
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 77
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 78
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 79
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 80
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 81
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 82
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 83
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 84
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 85
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 86
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 87
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 88
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 89
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 90
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 91
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 92
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 93
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 94
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 95
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 96
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 97
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 98
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 99
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 100
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 101
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 102
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 103
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 104
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 105
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 106
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 107
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 108
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 109
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 110
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 111
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 112
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 113
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 114
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 115
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 116
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 117
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 118
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 119
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 120
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 121
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 122
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 123
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 124
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 125
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 126
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 127
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 128
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 129
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 130
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 131
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 132
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 133
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 134
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 135
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 136
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 137
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 138
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 139
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 140
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 141
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 142
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 143
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 144
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 145
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 146
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 147
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 148
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 149
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 150
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 151
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 152
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 153
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 154
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 155
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 156
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 157
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 158
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 159
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 160
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 161
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 162
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 163
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 164
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 165
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 166
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 167
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 168
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 169
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 170
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 171
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 172
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 173
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 174
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 175
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 176
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 177
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 178
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 179
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 180
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 181
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 182
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 183
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 184
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 185
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 186
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 187
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 188
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 189
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 190
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 191
# processing /home/exacloud/gscratch/HeiserLab/images/AU02001/Analysis/CK/intermediate_files/AU02001_C_A1_1_reg_stack.tif index 192
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_205423/1447350480.py in <module>
#      94
#      95          # Open the nuclear mask stack:
# ---> 96         im = Image.open(mask_filename.replace('masks', 'nmasks'))
#      97
#      98         # create an index variable:
#
# NameError: name 'mask_filename' is not defined

# %% [markdown]
# #### Track the nuclei
# Use the KIT-Loeffler tracking method to track the masks and the nuclei
# For now, use the string below to run from the tracking script from the command line
# The tracking output includes masks with new label values and a res_track.txt file as described below

# %%
cmd = "python -m run_tracking --image_path "+ tracking_path+well+"/"+str(field)+"/reg/ --segmentation_path "+tracking_path+well+"/"+str(field)+"/masks/ --results_path "+tracking_path+well+"/"+str(field)+"/results --delta_t 3 --default_roi_size 2"
returned_value = os.system(cmd)  # returns the exit code in unix
print('returned value:', returned_value)
# Out:
# ####################
# time point: 0
# ####################
# ####################
# time point: 1
# ####################
# ####################
# time point: 2
# ####################
# ####################
# time point: 3
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 3106.05
# ####################
# time point: 4
# ####################
# ####################
# time point: 5
# ####################
# ####################
# time point: 6
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 7762.34
# ####################
# time point: 7
# ####################
# ####################
# time point: 8
# ####################
# ####################
# time point: 9
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 9448.86
# ####################
# time point: 10
# ####################
# ####################
# time point: 11
# ####################
# ####################
# time point: 12
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 10307.5
# ####################
# time point: 13
# ####################
# ####################
# time point: 14
# ####################
# ####################
# time point: 15
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 10042.9
# ####################
# time point: 16
# ####################
# ####################
# time point: 17
# ####################
# ####################
# time point: 18
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 10223.6
# ####################
# time point: 19
# ####################
# ####################
# time point: 20
# ####################
# ####################
# time point: 21
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 10889.2
# ####################
# time point: 22
# ####################
# ####################
# time point: 23
# ####################
# ####################
# time point: 24
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 10182.3
# ####################
# time point: 25
# ####################
# ####################
# time point: 26
# ####################
# ####################
# time point: 27
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 7220.26
# ####################
# time point: 28
# ####################
# ####################
# time point: 29
# ####################
# ####################
# time point: 30
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 6914.5
# ####################
# time point: 31
# ####################
# ####################
# time point: 32
# ####################
# ####################
# time point: 33
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 12130.3
# ####################
# time point: 34
# ####################
# ####################
# time point: 35
# ####################
# ####################
# time point: 36
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 7489.12
# ####################
# time point: 37
# ####################
# ####################
# time point: 38
# ####################
# ####################
# time point: 39
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 10971.9
# ####################
# time point: 40
# ####################
# ####################
# time point: 41
# ####################
# ####################
# time point: 42
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 10049.9
# ####################
# time point: 43
# ####################
# ####################
# time point: 44
# ####################
# ####################
# time point: 45
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 7969.02
# ####################
# time point: 46
# ####################
# ####################
# time point: 47
# ####################
# ####################
# time point: 48
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 10600
# ####################
# time point: 49
# ####################
# ####################
# time point: 50
# ####################
# ####################
# time point: 51
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 10430.6
# ####################
# time point: 52
# ####################
# ####################
# time point: 53
# ####################
# ####################
# time point: 54
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 10951.8
# ####################
# time point: 55
# ####################
# ####################
# time point: 56
# ####################
# ####################
# time point: 57
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 14528.4
# ####################
# time point: 58
# ####################
# ####################
# time point: 59
# ####################
# ####################
# time point: 60
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 8177.12
# ####################
# time point: 61
# ####################
# ####################
# time point: 62
# ####################
# ####################
# time point: 63
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 13008.8
# ####################
# time point: 64
# ####################
# ####################
# time point: 65
# ####################
# ####################
# time point: 66
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 16560.3
# ####################
# time point: 67
# ####################
# ####################
# time point: 68
# ####################
# ####################
# time point: 69
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 13514.1
# ####################
# time point: 70
# ####################
# ####################
# time point: 71
# ####################
# ####################
# time point: 72
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 9713.13
# ####################
# time point: 73
# ####################
# ####################
# time point: 74
# ####################
# ####################
# time point: 75
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 9253.67
# ####################
# time point: 76
# ####################
# ####################
# time point: 77
# ####################
# ####################
# time point: 78
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 9255.02
# ####################
# time point: 79
# ####################
# ####################
# time point: 80
# ####################
# ####################
# time point: 81
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 9909.14
# ####################
# time point: 82
# ####################
# ####################
# time point: 83
# ####################
# ####################
# time point: 84
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 10438.2
# ####################
# time point: 85
# ####################
# ####################
# time point: 86
# ####################
# ####################
# time point: 87
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 10483.7
# ####################
# time point: 88
# ####################
# ####################
# time point: 89
# ####################
# ####################
# time point: 90
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 10361.1
# ####################
# time point: 91
# ####################
# ####################
# time point: 92
# ####################
# ####################
# time point: 93
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 10708.4
# ####################
# time point: 94
# ####################
# ####################
# time point: 95
# ####################
# ####################
# time point: 96
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 11200.9
# ####################
# time point: 97
# ####################
# ####################
# time point: 98
# ####################
# ####################
# time point: 99
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 11495.3
# ####################
# time point: 100
# ####################
# ####################
# time point: 101
# ####################
# ####################
# time point: 102
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 12296.7
# ####################
# time point: 103
# ####################
# ####################
# time point: 104
# ####################
# ####################
# time point: 105
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 12599.4
# ####################
# time point: 106
# ####################
# ####################
# time point: 107
# ####################
# ####################
# time point: 108
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 12803.7
# ####################
# time point: 109
# ####################
# ####################
# time point: 110
# ####################
# ####################
# time point: 111
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 13226.7
# ####################
# time point: 112
# ####################
# ####################
# time point: 113
# ####################
# ####################
# time point: 114
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 13688.6
# ####################
# time point: 115
# ####################
# ####################
# time point: 116
# ####################
# ####################
# time point: 117
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 13231.9
# ####################
# time point: 118
# ####################
# ####################
# time point: 119
# ####################
# ####################
# time point: 120
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 13188.4
# ####################
# time point: 121
# ####################
# ####################
# time point: 122
# ####################
# ####################
# time point: 123
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 13783.6
# ####################
# time point: 124
# ####################
# ####################
# time point: 125
# ####################
# ####################
# time point: 126
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 13506.8
# ####################
# time point: 127
# ####################
# ####################
# time point: 128
# ####################
# ####################
# time point: 129
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 13378.7
# ####################
# time point: 130
# ####################
# ####################
# time point: 131
# ####################
# ####################
# time point: 132
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 13940.3
# ####################
# time point: 133
# ####################
# ####################
# time point: 134
# ####################
# ####################
# time point: 135
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 14008.6
# ####################
# time point: 136
# ####################
# ####################
# time point: 137
# ####################
# ####################
# time point: 138
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 13755.4
# ####################
# time point: 139
# ####################
# ####################
# time point: 140
# ####################
# ####################
# time point: 141
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 14204
# ####################
# time point: 142
# ####################
# ####################
# time point: 143
# ####################
# ####################
# time point: 144
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 14273.3
# ####################
# time point: 145
# ####################
# ####################
# time point: 146
# ####################
# ####################
# time point: 147
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 14978.3
# ####################
# time point: 148
# ####################
# ####################
# time point: 149
# ####################
# ####################
# time point: 150
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 15509.3
# ####################
# time point: 151
# ####################
# ####################
# time point: 152
# ####################
# ####################
# time point: 153
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 15214.8
# ####################
# time point: 154
# ####################
# ####################
# time point: 155
# ####################
# ####################
# time point: 156
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 15117.4
# ####################
# time point: 157
# ####################
# ####################
# time point: 158
# ####################
# ####################
# time point: 159
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 14780.1
# ####################
# time point: 160
# ####################
# ####################
# time point: 161
# ####################
# ####################
# time point: 162
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 15362.3
# ####################
# time point: 163
# ####################
# ####################
# time point: 164
# ####################
# ####################
# time point: 165
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 15803.7
# ####################
# time point: 166
# ####################
# ####################
# time point: 167
# ####################
# ####################
# time point: 168
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 16608.1
# ####################
# time point: 169
# ####################
# ####################
# time point: 170
# ####################
# ####################
# time point: 171
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 17542.8
# ####################
# time point: 172
# ####################
# ####################
# time point: 173
# ####################
# ####################
# time point: 174
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 17292
# ####################
# time point: 175
# ####################
# ####################
# time point: 176
# ####################
# ####################
# time point: 177
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 17206
# ####################
# time point: 178
# ####################
# ####################
# time point: 179
# ####################
# ####################
# time point: 180
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 18048
# ####################
# time point: 181
# ####################
# ####################
# time point: 182
# ####################
# ####################
# time point: 183
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 19210.3
# ####################
# time point: 184
# ####################
# ####################
# time point: 185
# ####################
# ####################
# time point: 186
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 17606.6
# ####################
# time point: 187
# ####################
# ####################
# time point: 188
# ####################
# ####################
# time point: 189
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 16463.7
# ####################
# time point: 190
# ####################
# ####################
# time point: 191
# ####################
# ####################
# time point: 192
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 17621.9
# untangle
# detangling - set up equations
# detangling - solve optim problem
# Using license file /opt/gurobi/gurobi.lic
# Set parameter TokenServer to value matlablic.ohsu.edu
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (linux64)
# Thread count: 28 physical cores, 28 logical processors, using up to 28 threads
# Optimize a model with 34683 rows, 24405 columns and 108247 nonzeros
# Model fingerprint: 0x85b97c6e
# Variable types: 0 continuous, 24405 integer (15559 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+05]
#   Objective range  [1e+00, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+00]
# Found heuristic solution: objective 5677.0000000
# Presolve removed 33614 rows and 23199 columns
# Presolve time: 0.33s
# Presolved: 1069 rows, 1206 columns, 3648 nonzeros
# Found heuristic solution: objective 2787.0000000
# Variable types: 0 continuous, 1206 integer (838 binary)
#
# Root relaxation: objective 2.689464e+03, 111 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 2689.46427    0   29 2787.00000 2689.46427  3.50%     -    0s
# H    0     0                    2716.0000000 2689.46427  0.98%     -    0s
# *    0     0               0    2715.0000000 2715.00000  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 22
#   Cover: 27
#   Implied bound: 25
#   MIR: 12
#   StrongCG: 3
#   Flow cover: 71
#   Relax-and-lift: 1
#
# Explored 1 nodes (147 simplex iterations) in 0.37 seconds
# Thread count was 28 (of 28 available processors)
#
# Solution count 4: 2715 2716 2787 5677
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.715000000000e+03, best bound 2.715000000000e+03, gap 0.0000%
# Optimal objective: 2715
# {'m_565_566': 1, 'm_620_624': 1, 'e_17_582': 1, 's_406': 1, 's_1722': 1, 'e_39_436': 1, 'm_1203_1204': 1, 'e_68_723': 1, 'm_1691_1693': 1, 'm_1683_1692': 1, 's_1767': 1, 'm_489_492': 1, 's_627': 1, 's_769': 1, 'e_108_1320': 1, 'm_1209_1210': 1, 'e_520_724': 1, 's_886': 1, 'e_127_4251': 1, 'm_569_574': 1, 'e_137_2101': 1, 'm_144_348': 1, 'm_863_885': 1, 'e_147_3738': 1, 's_1278': 1, 'm_1097_1098_1100': 1, 's_685': 1, 'e_189_504': 1, 's_856': 1, 's_686': 1, 'e_202_473': 1, 'e_228_3184': 1, 'e_230_498': 1, 'm_921_922': 1, 's_584': 1, 'm_963_964': 1, 'm_999_1028': 1, 's_1769': 1, 'e_264_859': 1, 's_585': 1, 'm_1111_1112': 1, 'm_318_363': 1, 'm_925_926': 1, 'm_448_461': 1, 'm_439_462': 1, 'e_4471_5575': 1, 'm_465_466': 1, 'm_656_657': 1, 'm_827_828': 1, 'm_1387_1389': 1, 's_719': 1, 's_497': 1, 's_1727': 1, 'm_1191_1226': 1, 's_940': 1, 'e_339_680': 1, 's_3793': 1, 'm_612_613': 1, 'm_604_605': 1, 's_581': 1, 's_437': 1, 's_722': 1, 'm_483_484': 1, 'm_915_916': 1, 's_678': 1, 'm_481_487': 1, 'e_424_435': 1, 'e_427_1074': 1, 'm_1786_1787': 1, 's_503': 1, 'm_2065_2067': 1, 'm_438_447': 1, 'm_1010_1012': 1, 's_3526': 1, 'm_1090_1119': 1, 'm_668_673': 1, 's_474': 1, 'e_469_472': 1, 'e_473_497': 1, 'm_475_480': 1, 'e_488_501': 1, 's_1030': 1, 'e_490_1337': 1, 's_583': 1, 'm_640_674': 1, 'm_652_653': 1, 'm_514_562': 1, 'e_516_810': 1, 'm_798_803': 1, 's_720': 1, 's_809': 1, 'm_929_932': 1, 'm_616_617': 1, 'm_755_756': 1, 'm_666_667': 1, 'm_969_970': 1, 'm_971_1093': 1, 's_541': 1, 'e_555_942': 1, 'e_560_872': 1, 'm_789_790': 1, 'm_1168_1170': 1, 'e_572_1029': 1, 's_690': 1, 'm_745_746': 1, 'm_1755_1764': 1, 'e_588_771': 1, 'e_606_936': 1, 's_684': 1, 's_772': 1, 'e_614_1338': 1, 'e_615_629': 1, 'e_619_939': 1, 'm_713_714': 1, 'm_1121_1132': 1, 's_808': 1, 'm_1175_1176': 1, 's_687': 1, 'e_650_688': 1, 's_681': 1, 's_2950': 1, 'e_661_859': 1, 'e_662_774': 1, 'e_664_4666': 1, 's_1033': 1, 'm_844_848': 1, 'm_1281_1283': 1, 's_934': 1, 's_937': 1, 'e_718_1776': 1, 'm_791_792': 1, 'm_1008_1009': 1, 'm_1566_1567': 1, 'e_749_1136': 1, 's_773': 1, 'e_753_774': 1, 'e_754_806': 1, 's_811': 1, 's_854': 1, 'm_1054_1055': 1, 'm_874_875': 1, 's_857': 1, 'm_835_836': 1, 's_890': 1, 's_892': 1, 'm_910_911': 1, 's_979': 1, 's_855': 1, 's_850': 1, 's_851': 2, 's_891': 1, 's_852': 1, 'm_1013_1014': 1, 's_1035': 2, 'e_876_2676': 1, 's_888': 1, 's_935': 1, 'e_884_1231': 1, 'm_965_966_967': 1, 'm_3493_3494': 1, 's_933': 1, 's_1034': 1, 's_1037': 2, 's_1032': 1, 'e_950_983': 1, 'm_3671_3674': 1, 's_980': 1, 's_978': 1, 's_1142': 1, 's_1072': 1, 'e_1005_1077': 1, 'e_1006_1139': 1, 's_1135': 1, 'e_1021_1071': 1, 'e_1022_3795': 1, 'm_1106_1108': 1, 's_1078': 1, 's_1146': 1, 'm_1123_1134': 1, 'e_1070_1079': 1, 'm_1462_1489_1572': 1, 'm_1086_1087': 1, 'e_1096_1233': 1, 's_1227': 1, 's_1140': 1, 'm_3576_3582': 1, 'e_1117_1607': 1, 'e_1120_1187': 1, 's_1228': 1, 's_1325': 1, 'e_1233_1884': 1, 'm_1343_1345': 1, 's_1809': 1, 's_1366': 1, 'm_2153_2154': 1, 's_2350': 1, 's_3208': 1, 'e_1312_1612': 1, 'm_1376_1377': 1, 'e_1322_1339': 1, 'e_1334_1830': 1, 'm_1700_1713': 1, 'm_1577_1590': 1, 's_1831': 1, 'e_1392_4699': 1, 'e_1393_3947': 1, 'e_1400_5126': 1, 'm_1405_1535': 1, 'm_1652_1653': 1, 'm_1448_1572': 1, 's_1606': 1, 's_1768': 1, 's_1609': 1, 'm_1479_1564': 1, 'e_1482_3385': 1, 'm_2362_2363': 1, 'e_1492_1726': 1, 's_1605': 1, 's_1611': 1, 's_2960': 1, 'm_3408_3409_3410': 1, 'e_1576_3823': 1, 's_3225': 1, 'm_1696_1709': 1, 's_3015': 1, 's_1728': 1, 's_1900': 1, 'e_1655_3427': 1, 'e_1659_2658': 1, 's_1723': 1, 'm_1673_1674': 1, 'm_6240_6251': 1, 'e_1717_1729': 1, 's_3316': 1, 'm_2129_2130': 1, 'e_1770_5473': 1, 'e_1776_2141': 1, 's_4250': 1, 's_2107': 1, 's_1810': 1, 'e_1798_4595': 1, 'e_1805_4662': 1, 'e_1822_2105': 1, 's_2143': 1, 's_3315': 1, 'm_2696_2701': 1, 's_1861': 1, 's_1901': 1, 's_1885': 1, 's_1883': 1, 'm_2014_2089': 1, 'e_1895_2642': 1, 's_2106': 1, 's_2100': 1, 's_3149': 1, 'm_3323_3324': 1, 'e_2070_3224': 1, 'e_2076_5671': 1, 's_2145': 1, 'm_2326_2338': 1,  ...
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
#
# add dummy masks
# export masks
# returned value: 0

# %% [markdown]
# #### Identify cells
# Read in the tracking results
# res_track.txt - A text file representing an acyclic graph for the whole image sequence. Every line corresponds to a single track that is encoded by four numbers separated by a space:
# L B E P where
# L - a unique label of the track (label of markers, 16-bit positive value)
# B - a zero-based temporal index of the frame in which the track begins
# E - a zero-based temporal index of the frame in which the track ends
# P - label of the parent track (0 is used when no parent is defined)
#
#
# Filter the track objects keeping the parents and those with a minimum track length and save the results to tracks.csv
#
# Create a new file tracks.csv with the following columns:
# label - a unique label of the track (label of markers, 16-bit positive value)
# begins - a zero-based temporal index of the frame in which the track begins
# ends - a zero-based temporal index of the frame in which the track ends
# parent - label of the parent track (0 is used when no parent is defined)
# length - The number of frames that the cell is identified in
# plateID - Character string of the plate's ID such as AU02001
# well - Character string of the well such as A1
# field - Integer of the image field within the well

# %%
#set filter parameters
min_track_length = 3
#loop through the results from each segmented field
for subdir in subdirectories:
    field = re.findall("field_[1-9]",subdir)[0]
    res_filename = os.path.join(output_path,"tracking",well,field,"results","res_track.txt")
    res_flt_filename = res_filename.replace("res_track.txt","tracks.csv")
    tracks = pd.read_csv(res_filename, sep=" ", header=None)
    tracks.columns = ["label", "begins", "ends", "parent"]
    tracks['length'] = tracks.ends - tracks.begins + 1
    #check if object is a parent
    tracks["is_parent"] = tracks['label'].isin(tracks['parent'])
    tracks['plateID'] = plateID
    tracks['well'] = well
    tracks['field'] = field.replace("field_","")
    #If filtered results do not exist, read in the res_track.txt file for the current field
    if not os.path.exists(res_flt_filename):
        #Filter using the filter parameters
        #remove short tracks that are not parents
        tracks_flt = tracks.query('length >= @min_track_length or is_parent')
        ##remove any track that appears after the first frame and doesn't have a parent
        #tracks_flt = tracks_flt.query('not (begins > 1 & parent == 0)')
        #write out the res_flt_track.txt file
        tracks_flt.to_csv(res_flt_filename,index=False)

# %% [markdown]
# #### Filter masks to only tracked cells
# Use the filtered tracks to remove masks for non-cell objects
# Save the filtered masks as individual image files in filtered_masks directory

# %%
#TODO make conditional on no filtered mask files#loop through the fields in the well
for subdir in subdirectories:
    field = re.findall("field_[1-9]",subdir)[0]
    res_flt_filename = os.path.join(output_path,"tracking",well,field,"results","tracks.csv")
    mask_track_path = os.path.join(output_path,"tracking",well,field,"results")
   #read in the tracks file for this field
    tracks = pd.read_csv(res_flt_filename) 
    #loop through the mask images in the field
    tracked_mask_filenames = sorted(glob.glob(mask_track_path+"/mask*"))
    # iterate over the mask files
    for fn in tracked_mask_filenames:
        #read in the mask image
        im = io.imread(fn)
        #replace any label that's not a cell with a 0 value
        cell_labels = np.array([x if x in tracks.label.to_numpy()
                                   else 0 for x in range(0, im.max()+1)])
        im_filtered = cell_labels[im]
        
        io.imsave(fn.replace("results","filtered_masks"), im_filtered.astype(np.int16), plugin='tifffile', check_contrast=False)

# %% [markdown]
# #### Find nuclei within each cytoplasmic mask
# Index through each filtered cytoplasmic mask and apply it to the red nuclear channel. Then run cellpose on the results to get nuclei masks. Count the number of masks in the cell and select one to represent the cell's nuclei. Either rebuild a single nuclear mask image to be applied alongside the cytoplasmic mask or pull the region properties and build a dataframe with enough metadata to join it with the cytoplasmic region data. Save the nuclear mask image and data.

# %% [markdown]
# ndiameter = 6
# flow_threshold = 2
# mask_threshold=0
# min_size=10
# resample = True
#
# #call cellpose on each image to segment the nuclei
# # DEFINE CELLPOSE MODEL
# model = models.Cellpose(gpu=True, model_type='nuclei')
#
# # define CHANNELS to run segementation on
# # grayscale=0, R=1, G=2, B=3
# # channels = [cytoplasm, nucleus]
# # if NUCLEUS channel does not exist, set the second channel to 0
# # will use grayscale image as nuclear channel only
# nchannels = [0,0]
#
# #loop through all fields in the well
# for subdir in subdirectories:
#     field = re.findall("field_[1-9]",subdir)[0]
#     nmask_filtered_path = os.path.join(output_path,"tracking",well,field,"nmasks")
#     nmask_filtered_filenames = glob.glob(nmask_filtered_path+"/nmask*") #see if any files exist
# if len(nmask_filtered_filenames) == 0: #Only segment if no nuclear mask file
#     print("creating nuclear masks for "+plateID+" "+well+" "+field)
#     #loop through the cyto mask images in the field
#     cmask_filenames = sorted(glob.glob(nmask_filtered_path.replace("nmasks","filtered_masks")+"/mask*"))
#     img_rs_reg = io.imread(output_path+plateID+"_R_"+well+"_"+field.replace("field_","")+"_reg_stack.tif")
#
#     for i, fn in enumerate(cmask_filenames[0:2]):
#         print("reading cyto masks " + fn)
#         im_cmask = io.imread(fn)
#         #step through each non-zero label
#         for cy_label in np.unique(im_cmask)[200:201]:
#             if not cy_label == 0:
#                 print("processing label " + str(cy_label))
#                 label_mask = (im_cmask == cy_label) #create a full size mask with true values only for the current label
#                 label_mask = np.ones(img_rs_reg[i].shape)*label_mask
#                 nuc_int = np.where(im_cmask == cy_label,img_rs_reg[i], np.zeros(img_rs_reg[i].shape))
#                 #nuc_int = img_rs_reg[i]*label_mask #apply the full size mask and get a full size intensity image with only intensties within the mask area
#                 #run cellpose nuclei model on the image
#                 nmasks, flows, styles, diams = model.eval(nuc_int,
#                                              diameter=ndiameter,
#                                              flow_threshold=flow_threshold,
#                                              mask_threshold=mask_threshold,
#                                              channels=nchannels,
#                                              min_size=10,
#                                              resample = resample)

# %% [markdown]
# #### Get excel metadata file
# If this file does not exists, cretae a level 0 file that is data only

# %%
#If the metadata exists, join it to the data and write out as a level 1 file
metadata_filename = os.path.join(data_path,plateID,"metadata",plateID+".xlsx")

if os.path.exists(metadata_filename):
    md_all = pd.read_excel(metadata_filename, engine='openpyxl', dtype={'Drug1Concentration': str, 'Drug2Concentration': str})
    
    #remove unwanted columns read in from the excel files
    r = re.compile("Unnamed.*")
    columns_to_drop = list(filter(r.match, md_all.columns)) 
    metadata = md_all.drop(columns = columns_to_drop)
    
    #match metadata and data well labels format
    metadata['row'] = [re.sub(r'[0-9]*', '', Well) for Well in metadata['Well']]
    metadata['column'] = [re.sub(r'[A-Z]', '', Well) for Well in metadata['Well']]
    metadata['column'] = [re.sub(r'\A0', '', row) for row in metadata['column']]
    metadata['well'] = metadata['row'] + metadata['column']

# %% [markdown]
# #### Pull data from images
# Apply the filtered masks to the registered cytoplasmic channel and record each cell's cytoplasmic morphology, intensity and texture
# Apply the nuclear masks to the registered red channel and record each cell's nuclear morphology, intensity and texture
# If the metadata is available, merge it with the cyoplasmic data
# Store the cytoplasmic cell level data (and metadata) in a csv file where each row is a cell
# Store the nuclear cell level data (and limited metadata) in a csv file where each row is a cell
# Data feature values can be decoded as follows:
# \<compartment>\_\<pipeline name>\_\<channel name>\_\<regionprops name>
# compartment - Nuclei, Cyto or Cell
# pipeline name - CK for cellpose KIT or other if added
# channel name - NR for nuclear reporter, CC for cell cycle reporter or others if added
# regionprops name - label passed through from the skimage measure.regionprops function https://scikit-image.org/docs/dev/api/skimage.measure.html#skimage.measure.regionprops

# %%
minutes_between_images = 30

#loop through the fields in the well

for subdir in subdirectories:
    field = re.findall("field_[1-9]",subdir)[0]
    filtered_mask_path = os.path.join(output_path,"tracking",well,field,"filtered_masks")
    cy_tracked_mask_filenames = sorted(glob.glob(filtered_mask_path+"/mask*"))
    l0_filename = os.path.join(data_path+plateID,"Analysis",pipeline_name,plateID+"_"+well+"_"+field+"_cell_level_0.csv")
    img_ps_reg = io.imread(output_path+plateID+"_P_"+well+"_"+field.replace("field_","")+"_reg_stack.tif")
    img_rs_reg = io.imread(output_path+plateID+"_R_"+well+"_"+field.replace("field_","")+"_reg_stack.tif")
    img_gs_reg = io.imread(output_path+plateID+"_G_"+well+"_"+field.replace("field_","")+"_reg_stack.tif")
    # iterate over the cyto mask files
    cell_results = []
    for i, fn in enumerate(cy_tracked_mask_filenames):
        #read in the cytoplasm mask image
        masks = io.imread(fn)
 
        #measure cell cycle reporter intensity and cellular morphology, texture
        cyto_cell_cycle = measure.regionprops_table(masks, intensity_image=img_gs_reg[i],
                                           properties=('label',
                                                       'area','bbox_area','convex_area','centroid','eccentricity','equivalent_diameter','extent','feret_diameter_max','filled_area',
                                                        'major_axis_length','minor_axis_length','moments_hu','perimeter','perimeter_crofton','solidity',
                                                        'mean_intensity','max_intensity','min_intensity'))
    
        # turn results into a dataframe
        cyto_data = pd.DataFrame(cyto_cell_cycle)
        cyto_data.rename(columns={col: 'Cell_'+pipeline_name+'_' +ch2_name+'_'+col  for col in cyto_data.columns if col not in ['label']}, inplace=True)
       
        # recover the well, field and time slice values and add them to the dataframe
        well = re.findall('/[A-Z][0-9]+/',fn)[0]
        well = re.sub('/','', well)
        cyto_data['well'] = well
        field = re.findall('field_[0-9]+',fn)[0]
        field = int(re.sub('field_','', field))
        cyto_data['field'] = field
        cyto_data['slice'] = i
        elapsed_minutes = i*minutes_between_images #assumes time slice numbering starts at 1
        day = np.floor(elapsed_minutes/(24*60)).astype(int)
        hour = np.floor((elapsed_minutes-day*(24*60))/60).astype(int)
        minute = np.floor(elapsed_minutes-day*(24*60)-hour*60).astype(int)
        day = str(day).zfill(2)
        hour = str(hour).zfill(2)
        minute = str(minute).zfill(2)
        cyto_data['time_slice'] = day+"d"+hour+"h"+minute+"m"
        
        #read in the nuclear mask image
        nfn = fn.replace("filtered_masks","nmasks")
        nfn = nfn.replace("/mask","/nmask")
        nmasks = io.imread(nfn)
 
        #measure cell cycle reporter intensity and nuclear morphology, texture
        nuc_cell_cycle = measure.regionprops_table(nmasks, intensity_image=img_gs_reg[i],
                                           properties=('label',
                                                       'area','bbox_area','convex_area','centroid','eccentricity','equivalent_diameter','extent','feret_diameter_max','filled_area',
                                                        'major_axis_length','minor_axis_length','moments_hu','perimeter','perimeter_crofton','solidity',
                                                        'mean_intensity','max_intensity','min_intensity'))
    
        # turn results into a dataframe
        nuc_data = pd.DataFrame(nuc_cell_cycle)
        nuc_data.rename(columns={col: 'Nuclei_'+pipeline_name+'_' +ch2_name+'_'+col  for col in nuc_data.columns if col not in ['label']}, inplace=True)
        nuc_data.rename(columns={"label": "nuc_label"}, inplace=True)
        # add the well, field and time slice values and add them to the dataframe
        #nuc_data['well'] = cyto_data['well']
        #nuc_data['field'] = cyto_data['field']
        #nuc_data['slice'] = cyto_data['slice']
        #nuc_data['time_slice'] = cyto_data['time_slice']

        #compute the distances between the cyto and nuclei centroids
        #Rows are cyto and columns are nuclei
        #smallest value in each row is the nearest nuclei to the cyto mask's centroid
        centroid_distances = pd.DataFrame(spatial.distance_matrix(cyto_data[['Cell_CK_CC_centroid-1', 'Cell_CK_CC_centroid-0']].to_numpy(),
        nuc_data[['Nuclei_CK_CC_centroid-1', 'Nuclei_CK_CC_centroid-0']].to_numpy()))

        #for each row, find the column with the smallest value
        nearest_nuclei = centroid_distances.idxmin(axis = 1)
        
        #add the nuclear label to the cyto data
        cyto_data['nuclei_label'] = nearest_nuclei
        
        #merge the cyto and nuclear data on the label
        cell_data = pd.merge(cyto_data, nuc_data, left_on='nuclei_label', right_on='nuc_label')
        
        # append the dataframe to the results list
        cell_results.append(cell_data)

    #concatenate all of the results from the images in the field
    l0 = pd.concat(cell_results)

    #join with the tracking results to get lineage, parent, frame length values
    tracks_filename = os.path.join(output_path,"tracking",well,"field_"+str(field),"results/tracks.csv")
    tracks = pd.read_csv(tracks_filename)
    l0 = pd.merge(l0, tracks, how="left", on=["label", "well", "field"])

    if os.path.exists(metadata_filename):
        #merge data and metadata on well values
        l1= pd.merge(l0, metadata, how="left", on=["well"]).round(decimals=2)
        l1.to_csv(l0_filename.replace('level_0','level_1'), index = False)
    else:
        print("no metadata file for "+plateID+" so creating level 0 file")
        l0 = l0.round(decimals=2)
        l0.to_csv(l0_filename, index = False)
