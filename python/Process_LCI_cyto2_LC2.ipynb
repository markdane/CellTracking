# %%
#setup libraries
import numpy as np
import numpy.ma as ma
import pandas as pd
import os, re, glob, sys
from skimage import io, filters, util, segmentation, morphology, measure, restoration, exposure
from skimage.registration import phase_cross_correlation
import matplotlib.pyplot as plt
#import imageio
from cellpose import models, plot
from scipy import stats, spatial, ndimage
from PIL import Image, ImageSequence
import tifffile

# %%
pipeline_name = "CKcn" #cellpose, KIT tracking cell and nuclei segmentation
ch1_name = 'NR'
ch2_name = 'CC'
data_path = '/home/exacloud/gscratch/HeiserLab/images/'
#data_path = '/Users/dane/Documents/CellTrackingProjects/AU565/images/'
#data_path = '/Users/dane/Documents/CellTrackingProjects/HCC1143/images/'
plateID = 'HC00801'
#plateID = sys.argv[1]
well_index = 1
#well_index = int(sys.argv[2])

output_path = os.path.join(data_path+plateID,"Analysis",pipeline_name,"intermediate_files/")
registered_stacks_path = os.path.join(data_path+plateID,"Analysis","registered_stacks")
transformation_path = os.path.join(registered_stacks_path,"transformations")
tracking_path = os.path.join(output_path,'tracking/')

#Only use subdirectories within the selected well
well_directory = sorted(glob.glob(os.path.join(data_path+plateID,"[A-Z][1-9]")))[well_index-1]
well = re.findall("[A-Z][1-9]$",well_directory)[0]
subdirectories = sorted(glob.glob(os.path.join(well_directory,"field_[1-9]")))

# %% [markdown]
# #### Register the image stacks
# If there is a registered red channel stack skip this step, otherwise:
# Load the red, green and phase images
# Delete images from any time slice that does not have a complete set of images
# Rescale the fluorescent images from 12 to 8 bits
# Calculate the transformations needed to register the red stack, correcting the translation only
# Store the registration transformations
# Use the transformations to register all three stacks
# Save the registered stacks as 16 bit images

# %%
for subdir in subdirectories:
    field = re.findall("field_[1-9]",subdir)[0]
    field_num = re.findall("[0-9]", field)[0]
    reg_filename = os.path.join(registered_stacks_path,plateID+"_R_"+well+"_"+field_num+"_reg_stack.tif")
    # Only process the field-level image files if registered stacks are missing
    if not np.logical_and(np.logical_and(os.path.exists(reg_filename),os.path.exists(reg_filename.replace("_R_", "_P_"))),os.path.exists(reg_filename.replace("_R_", "_G_"))):
        print("Gathering image stacks for "+subdir)
        #load and prepare red, green and phase channels. Scale for 8 bits but these are uint16 data types
        r_data_paths = glob.glob(os.path.join(subdir,"*_R_*m.tif"))
        r_time_slices = set()
        for data_paths in r_data_paths:
            r_time_slices.add(re.findall("..d..h..m", data_paths)[0])
        g_data_paths = glob.glob(os.path.join(subdir,"*_G_*m.tif"))
        g_time_slices = set()
        for data_paths in g_data_paths:
            g_time_slices.add(re.findall("..d..h..m", data_paths)[0])
        p_data_paths = glob.glob(os.path.join(subdir,"*_P_*m.tif"))
        p_time_slices = set()
        for data_paths in p_data_paths:
            p_time_slices.add(re.findall("..d..h..m", data_paths)[0])
        complete_time_slices = r_time_slices & g_time_slices & p_time_slices
        r_data_paths_c = []
        g_data_paths_c = []
        p_data_paths_c = []
        for time_slice in complete_time_slices:
            r_data_paths_c.append(os.path.join(data_path+plateID,well,field,plateID+"_R_"+well+"_"+field_num+"_"+time_slice+".tif"))
            g_data_paths_c.append(os.path.join(data_path+plateID,well,field,plateID+"_G_"+well+"_"+field_num+"_"+time_slice+".tif"))
            p_data_paths_c.append(os.path.join(data_path+plateID,well,field,plateID+"_P_"+well+"_"+field_num+"_"+time_slice+".tif"))
        img_r_ic = io.imread_collection(r_data_paths_c) # 3 dimensions : frames x width x height
        img_rs = np.stack(img_r_ic)

        img_g_ic = io.imread_collection(g_data_paths_c) # 3 dimensions : frames x width x height
        img_gs = np.stack(img_g_ic)

        img_p_ic = io.imread_collection(p_data_paths_c) # 3 dimensions : frames x width x height
        img_ps = np.stack(img_p_ic)
        
        #register using skimage skimage.registration phase_cross_correlation
        shifts = np.zeros([img_ps.shape[0], 2])
        img_rs_reg = img_rs
        img_gs_reg = img_gs
        img_ps_reg = img_ps
        print("calculating shifts")
        for i, image in enumerate(img_ps[range(img_ps.shape[0]-1)]): #loop through the first to the second to last image
            shift, error, diffphase = phase_cross_correlation(image, img_ps[i+1], normalization=None, upsample_factor=4)
            #print(str(i)+" shift: "+str(shift))
            shifts[i+1] = shifts[i]+shift #make shifts absolute, based on first image
            #print(str(i)+" absolute shift: "+str(shifts[i+1]))
        print("shifting image stacks")
        for i in range(img_ps.shape[0]):
            img_rs_reg[i] = ndimage.shift(img_rs[i], shifts[i], order=3, mode='constant', cval=0, prefilter=True)
            img_gs_reg[i] = ndimage.shift(img_gs[i], shifts[i], order=3, mode='constant', cval=0, prefilter=True)
            img_ps_reg[i] = ndimage.shift(img_ps[i], shifts[i], order=3, mode='constant', cval=0, prefilter=True)
            
        if not os.path.exists(transformation_path):
            os.makedirs(transformation_path)
        np.save(os.path.join(transformation_path,plateID+"_"+well+"_"+field+"_shifts.npy"), shifts)

        #assume transformations are in pixels and crop images to exclude areas that are outside of any registered image
        x_axis_length = img_rs_reg.shape[2]
        y_axis_length = img_rs_reg.shape[1]
        
        #crop each stack to the area that is common in all images after registration
        #use the min and max values in the transformation stack to define the common active area 
        x_max = shifts[:,1].max().astype("int")
        x_min = shifts[:,1].min().astype("int")
        y_max = shifts[:,0].max().astype("int")
        y_min = shifts[:,0].min().astype("int")
        
        #assume transformations are in pixels and crop images to exclude areas that are outside of any registered image
        x_axis_length = img_rs_reg.shape[2]
        y_axis_length = img_rs_reg.shape[1]
        print("Cropping to active areas for "+subdir)
        
        img_rs_reg_crop = img_rs_reg[:,np.max([0, y_max]):(y_axis_length+np.min([0,y_min])),np.max([0, x_max]):(x_axis_length+np.min([0,x_min]))]
        img_gs_reg_crop = img_gs_reg[:,np.max([0, y_max]):(y_axis_length+np.min([0,y_min])),np.max([0, x_max]):(x_axis_length+np.min([0,x_min]))]
        img_ps_reg_crop = img_ps_reg[:,np.max([0, y_max]):(y_axis_length+np.min([0,y_min])),np.max([0, x_max]):(x_axis_length+np.min([0,x_min]))]
        print("Saving stacks to disk for "+subdir)
        io.imsave(reg_filename, img_rs_reg_crop.astype(np.int16), plugin='tifffile', check_contrast=False)
        io.imsave(reg_filename.replace("_R_","_G_"), img_gs_reg_crop.astype(np.int16), plugin='tifffile', check_contrast=False)
        io.imsave(reg_filename.replace("_R_","_P_"), img_ps_reg_crop.astype(np.int16), plugin='tifffile', check_contrast=False)

# %% [markdown]
# #### Segment the nuclear fluorescent images using cellpose
# If mask files already exist, skip this step, otherwise:
# Load the registered phase and red stack nuclear marker images
# Segment cell outlines in the phase image and only keep masks between two thresholds
# Save the mask files as an image sequence
# For compatibility with the tracking method, save the masks and the nuclear intensity images as indivdual files

# %%
def select_cellpose_n_diameter(x):
    return {'AU00601': 13,'AU01501': 13,'AU01601': 13,'AU01701': 13,'AU01702': 13,'AU01801': 13,'AU01802': 13,
        'AU01901': 13,
        'AU01902': 13,
        'AU02001': 13,
        'AU02002': 13,
        'AU02101': 13,
        'AU02201': 13,
        'AU02301': 13,
        'AU02201': 13,
        'AU02401': 13,
        'AU02501': 13,
        'AU02601': 13,
        'AU02701': 13,
        'AU02801': 13,
        'AU02901': 13,
        'AU03001': 13,
        'AU03101': 13,
        'AU03201': 13,
        'AU03301': 13,
        'AU03401': 13,
        'AU03501': 13,
        'AU03601': 13,
        'AU03701': 13,
        'HC00701': 17,
        'HC00801': 17,
        'HC00901': 17,
        'HC01001': 17,
        'HC01301': 17,
        '2100601': 28,
    }[x]

def select_cellpose_c_diameter(x):
    return {
        'AU00601': 25,
        'AU01501': 25,
        'AU01601': 25,
        'AU01701': 25,
        'AU01702': 25,
        'AU01801': 25,
        'AU01802': 25,
        'AU01901': 25,
        'AU01902': 25,
        'AU02001': 25,
        'AU02002': 25,
        'AU02101': 25,
        'AU02201': 25,
        'AU02301': 25,
        'AU02201': 25,
        'AU02401': 25,
        'AU02501': 25,
        'AU02601': 25,
        'AU02701': 25,
        'AU02801': 25,
        'AU02901': 25,
        'AU03001': 25,
        'AU03101': 25,
        'AU03201': 25,
        'AU03301': 25,
        'AU03401': 25,
        'AU03501': 25,
        'AU03601': 25,
        'AU03701': 25,
        'HC00701': 28,
        'HC00801': 28,
        'HC00901': 28,
        'HC01001': 28,
        'HC01301': 28,
        '2100601': 35,
    }[x]


def select_cc_intensity(x):
    return {
        'AU00601': 175,
        'AU01501': 175,
        'AU01601': 175,
        'AU01701': 175,
        'AU01702': 175,
        'AU01801': 175,
        'AU01802': 175,
        'AU01901': 175,
        'AU01902': 175,
        'AU02001': 175,
        'AU02002': 175,
        'AU02101': 175,
        'AU02201': 175,
        'AU02301': 175,
        'AU02201': 175,
        'AU02401': 175,
        'AU02501': 175,
        'AU02601': 175,
        'AU02701': 175,
        'AU02801': 175,
        'AU02901': 175,
        'AU03001': 175,
        'AU03101': 175,
        'AU03201': 175,
        'AU03301': 175,
        'AU03401': 175,
        'AU03501': 175,
        'AU03601': 175,
        'AU03701': 175,
        'HC00701': 175,
        'HC00801': 175,
        'HC00901': 175,
        'HC01001': 175,
        'HC01301': 175,
        '2100601': 50,
    }[x]

cyto_expansion = 5
n_diameter = select_cellpose_n_diameter(plateID)
c_diameter = select_cellpose_c_diameter(plateID)

flow_threshold = .5
cellprob_threshold=0
c_min_size=400 
c_max_size = 10000
n_min_size=60 #diamater = 8.8
n_max_size = 400
Cyto_CKn_CC_mean_intensity_threshold = select_cc_intensity(plateID)

resample = True

# DEFINE CELLPOSE MODELs
cell_model = models.CellposeModel(gpu=True, pretrained_model = "/home/users/dane/.cellpose/models/LC2")
nuc_model = models.Cellpose(gpu=True, model_type = "cyto2")

# define CHANNELS to run segementation on
# grayscale=0, R=1, G=2, B=3
# channels = [cytoplasm, nucleus]
# if NUCLEUS channel does not exist, set the second channel to 0
# will use channel R = 1 as nuclear channel only
c_channels = [0,0]
n_channels = [0,0]

for subdir in subdirectories:
    results = [] #collect results for one field in the well
    field = re.findall("field_[1-9]",subdir)[0]
    field_num = re.findall("[0-9]", field)[0]
    reg_filename = os.path.join(registered_stacks_path,plateID+"_R_"+well+"_"+field_num+"_reg_stack.tif")
    n_mask_filename = os.path.join(output_path,plateID+"_"+well+"_"+field_num+"_nuc_masks.png")
    c_mask_filename = os.path.join(output_path,plateID+"_"+well+"_"+field_num+"_cell_masks.png")
    cyto_mask_filename = os.path.join(output_path,plateID+"_"+well+"_"+field_num+"_cyto_masks.png")

    tracking_path = os.path.join(output_path,'tracking/')
    if not os.path.exists(tracking_path+well+"/"+field+"/nuc_masks/"):
            os.makedirs(tracking_path+well+"/"+field+"/nuc_masks/")
    if not os.path.exists(tracking_path+well+"/"+field+"/cell_masks/"):
            os.makedirs(tracking_path+well+"/"+field+"/cell_masks/")
    if not os.path.exists(tracking_path+well+"/"+field+"/cyto_masks/"):
            os.makedirs(tracking_path+well+"/"+field+"/cyto_masks/")
    if not os.path.exists(tracking_path+well+"/"+field+"/reg"):
            os.makedirs(tracking_path+well+"/"+field+"/reg")
    if not os.path.exists(tracking_path+well+"/"+field+"/results"):
            os.makedirs(tracking_path+well+"/"+field+"/results")
    if not os.path.exists(tracking_path+well+"/"+field+"/cyto_filtered_masks"):
            os.makedirs(tracking_path+well+"/"+field+"/cyto_filtered_masks")
    if not os.path.exists(tracking_path+well+"/"+field+"/nuc_filtered_masks"):
            os.makedirs(tracking_path+well+"/"+field+"/nuc_filtered_masks")
    if not np.logical_and(os.path.exists(n_mask_filename), os.path.exists(c_mask_filename)): #Only segment if no mask file
        print("Start segmenting "+plateID + " "+ well + " " + field)
        img_rs_reg = io.imread(reg_filename)
        img_gs_reg = io.imread(reg_filename.replace('_R_', '_G_'))
        img_ps_reg = io.imread(reg_filename.replace('_R_', '_P_'))

        c_mask_images = []
        cyto_mask_images = []
        n_mask_images = []
        for i, image in enumerate(img_ps_reg):
            # create cyto masks with cellpose 
            cell_masks, flows, styles = cell_model.eval(image,
                                                       diameter=c_diameter,
                                                       net_avg = True,
                                                        flow_threshold=flow_threshold,
                                                       cellprob_threshold=cellprob_threshold,
                                                       channels=n_channels,
                                                       min_size=c_min_size)
            #remove debris and false masks
            c_masks_filtered = np.copy(cell_masks)
            component_sizes = np.bincount(cell_masks.ravel())
            debris = np.logical_or(component_sizes < c_min_size, component_sizes > c_max_size)
            debris_mask = debris[cell_masks]
            c_masks_filtered[debris_mask] = 0

            #Make a list of the filtered cell mask full size images 
            c_mask_images.append(c_masks_filtered)
            
            #only look for nuclei within the cells
            cell_mask = c_masks_filtered>0
            nuc_image_masked = np.ma.masked_array(img_rs_reg[i], cell_mask).data
            
            #use the nuclear cellpose model to identify the nuclei within each cell
            n_masks, flows, styles, diams = nuc_model.eval(nuc_image_masked,
                                            diameter=n_diameter,
                                            net_avg = True,
                                            flow_threshold=flow_threshold,
                                            cellprob_threshold=cellprob_threshold,
                                            channels=n_channels)

            #use regionprops with the cell masks to get the nuclear labels
            nuc_images = measure.regionprops_table(c_masks_filtered, intensity_image=n_masks,
                                               properties=('label', 'image', 'image_intensity', 'bbox'))   
            #nuc_images is a list of bounding box images 
            #label is the cell label's value
            #image is a 2d logical array of the cell mask in it's bounding box
            #image_intensity is a 2d integer array of the nuclear masks in the cell's bounding box
            
            #Use the nuc_images list to create a new full image 2d nuclear mask where the nuclear mask values 
            #are the same as the cell masks they are within
            
            #create a dataframe with cell label, nuc label and nuc area columns where each row is a cell and the information comes from the cell bounding box
            cell_df_list = []
            
            for nuc_i, int_image in enumerate(nuc_images['image_intensity']): 
                #for each cell mask bounding box ...
                #remove nuclear masks that are outside the cell mask
                nuc_image = np.ma.masked_array(int_image, nuc_images['image'][nuc_i]).data
                
                #get the nuclei mask values inside each cell mask
                #need to handle these cases
                #nuclei are in more than one cell - assign to the cell with the most area
                #after nuclei are only in one cell...
                #no nuclei in the cell - delete cell mask
                #one nuclei in the cell - relabel the nuclei to the cell
                #more than one nuclei in the cell - relabel all nuclei to the cell
                
                unique_nuc_labels = np.unique(nuc_image[nuc_image != 0])
                #print("nuclear label(s) "+str(unique_nuc_labels)+" are in cell "+str(nuc_images['label'][nuc_i]))
                
                #for each mask, get the number of pixels inside the cell
                if(unique_nuc_labels.size != 0):
                    nuc_masks, counts = np.unique([element for element in nuc_image.ravel() if element != 0], return_counts=True)
                    cell_df = pd.DataFrame({'Cell': nuc_images['label'][nuc_i], 'Nuc_mask': nuc_masks, 'area':counts})
                    cell_df_list.append(cell_df)
                
            cell_df = pd.concat(cell_df_list, ignore_index = True)
            
            #use the cell dataframe to assign nuclei to cells based on max area in the cell
            cell_df = cell_df.sort_values(['area'],ascending=False).groupby('Nuc_mask').head(1).sort_index(ignore_index=True)
            
            #store the nuclei to cell assignments as a dictionary
            nuclei_cell = pd.Series(cell_df.Nuc_mask.values,index=cell_df.Cell).to_dict()

            #TODO Will need an example when there are two nuceli in a cell

            #build a new nuclei mask image with nuclei clipped to within one cell and using the cell's label 
            final_nuc_mask_image = np.zeros(n_masks.shape, like = n_masks)

            for cell_i, nuc_mask_image in enumerate(nuc_images['image_intensity']): #loop through each cell mask
                #don't process the nuclei if it's within a cell
                if(nuc_images['label'][cell_i] in cell_df['Cell'].to_numpy()):
                    #clip the nuclei to within the cell mask
                    nuc_masks_within_cell = np.ma.masked_array(nuc_mask_image, nuc_images['image'][cell_i]).data 
                    #zero out nuclei not associated with this cell
                    associated_nuclei = cell_df['Nuc_mask'][cell_df['Cell'] == nuc_images['label'][cell_i]].to_numpy()
                    nuc_associated_mask = np.isin(nuc_masks_within_cell, associated_nuclei)
                    nuc_associated = np.ma.masked_array(nuc_mask_image, nuc_associated_mask).data #clipped associated nuclei to the cell masks

                    #Relabel nuclei associated with this cell to the cell's label
                    nuc_associated[nuc_associated_mask] = nuc_images['label'][cell_i]

                    #Use the bounding box origin to add the nuclei to the final mask
                    min_row = nuc_images['bbox-0'][cell_i]
                    min_col = nuc_images['bbox-1'][cell_i]
                    max_row = nuc_images['bbox-2'][cell_i]
                    max_col = nuc_images['bbox-3'][cell_i]
                    final_nuc_mask_image[min_row:max_row,min_col:max_col] = nuc_associated
            
            
            #Make a list of the filtered cell mask full size images 
            c_mask_images.append(c_masks_filtered)
            
            #Make a list of the filtered nuclear mask full size images 
            n_mask_images.append(final_nuc_mask_image)
            
            #Make a list of cyto masks
            cyto_mask_images.append(c_masks_filtered-final_nuc_mask_image)
 
        tifffile.imwrite(n_mask_filename, np.array(n_mask_images, dtype = 'uint16'), imagej=True)
        tifffile.imwrite(c_mask_filename, np.array(c_mask_images, dtype = 'uint16'), imagej=True)
        tifffile.imwrite(cyto_mask_filename, np.array(cyto_mask_images, dtype = 'uint16'), imagej=True)

        # Open the nuclear mask stack:
        im = Image.open(n_mask_filename)

        # create an index variable:
        i =0
        app = []

        # iterate over the mask stack and save each frame to disk:
        print("Save individual nuclear masks to disk for "+reg_filename.replace('_R_', '_P_'))
        for fr in ImageSequence.Iterator(im):
            app.append(fr)
            fr.save(tracking_path+well+"/"+field+"/nuc_masks/"+"mask%03.d.tif"%i)
            i = i + 1

        # Open the cell mask stack:
        im = Image.open(c_mask_filename)

        # create an index variable:
        i =0
        app = []

        # iterate over the mask stack and save each frame to disk:
        print("Save individual cell masks to disk for "+reg_filename.replace('_R_', '_P_'))
        for fr in ImageSequence.Iterator(im):
            app.append(fr)
            fr.save(tracking_path+well+"/"+field+"/cell_masks/"+"mask%03.d.tif"%i)
            i = i + 1

        # Open the cyto mask stack:
        im = Image.open(cyto_mask_filename)

        # create an index variable:
        i =0
        app = []

        # iterate over the mask stack and save each frame to disk:
        print("Save individual cytoplasmic masks to disk for "+reg_filename.replace('_R_', '_P_'))
        for fr in ImageSequence.Iterator(im): 
            app.append(fr)
            fr.save(tracking_path+well+"/"+field+"/cyto_masks/"+"mask%03.d.tif"%i)
            i = i + 1

        # Open the registered intensity stack: use the phase images
        im = Image.open(reg_filename.replace('_R_', '_P_'))

        # create an index variable:
        i = 0
        app = []

        # iterate over the registered phase stack and save each frame to disk:
        for fr in ImageSequence.Iterator(im):
            app.append(fr)
            fr.save(tracking_path+well+"/"+field+"/reg/"+"t%03.d.tif"%i)
            i = i + 1

# %% [markdown]
# #### Track the nuclei
# Use the KIT-Loeffler tracking method to track the nuclei
# The tracking output includes masks with new label values and a res_track.txt file as described below

# %%
for subdir in subdirectories: #track all fields in the well
    field = re.findall("field_[1-9]",subdir)[0]
    #Condition on the tracking output file res_tracks.txt existing
    if not os.path.exists(tracking_path+well+"/"+str(field)+"/results/res_track.txt"): #Only track if no res_track.txt
        cmd = "python -m run_tracking --image_path "+ tracking_path+well+"/"+str(field)+"/reg/ --segmentation_path "+tracking_path+well+"/"+str(field)+"/cyto_masks/ --results_path "+tracking_path+well+"/"+str(field)+"/results --delta_t 3 --default_roi_size 2"
        returned_value = os.system(cmd)  # returns the exit code in unix
        print('returned value from command line tracking with KIT:', returned_value)
# Out:
# ####################
# time point: 0
# ####################
# ####################
# time point: 1
# ####################
# ####################
# time point: 2
# ####################
# ####################
# time point: 3
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 3158.76
# ####################
# time point: 4
# ####################
# ####################
# time point: 5
# ####################
# ####################
# time point: 6
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 7635.04
# ####################
# time point: 7
# ####################
# ####################
# time point: 8
# ####################
# ####################
# time point: 9
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 7703.48
# ####################
# time point: 10
# ####################
# ####################
# time point: 11
# ####################
# ####################
# time point: 12
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 8180.18
# ####################
# time point: 13
# ####################
# ####################
# time point: 14
# ####################
# ####################
# time point: 15
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 8025.42
# ####################
# time point: 16
# ####################
# ####################
# time point: 17
# ####################
# ####################
# time point: 18
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 8640.34
# ####################
# time point: 19
# ####################
# ####################
# time point: 20
# ####################
# ####################
# time point: 21
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 8796.91
# ####################
# time point: 22
# ####################
# ####################
# time point: 23
# ####################
# ####################
# time point: 24
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 8798.8
# ####################
# time point: 25
# ####################
# ####################
# time point: 26
# ####################
# ####################
# time point: 27
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 8888.24
# ####################
# time point: 28
# ####################
# ####################
# time point: 29
# ####################
# ####################
# time point: 30
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 9258.64
# ####################
# time point: 31
# ####################
# ####################
# time point: 32
# ####################
# ####################
# time point: 33
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 9492.89
# ####################
# time point: 34
# ####################
# ####################
# time point: 35
# ####################
# ####################
# time point: 36
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 9220.83
# ####################
# time point: 37
# ####################
# ####################
# time point: 38
# ####################
# ####################
# time point: 39
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 9500.52
# ####################
# time point: 40
# ####################
# ####################
# time point: 41
# ####################
# ####################
# time point: 42
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 9867.29
# ####################
# time point: 43
# ####################
# ####################
# time point: 44
# ####################
# ####################
# time point: 45
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 10337.4
# ####################
# time point: 46
# ####################
# ####################
# time point: 47
# ####################
# ####################
# time point: 48
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 10460.7
# ####################
# time point: 49
# ####################
# ####################
# time point: 50
# ####################
# ####################
# time point: 51
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 10334.5
# ####################
# time point: 52
# ####################
# ####################
# time point: 53
# ####################
# ####################
# time point: 54
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 10941.1
# ####################
# time point: 55
# ####################
# ####################
# time point: 56
# ####################
# ####################
# time point: 57
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 10455.4
# ####################
# time point: 58
# ####################
# ####################
# time point: 59
# ####################
# ####################
# time point: 60
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 10519.4
# ####################
# time point: 61
# ####################
# ####################
# time point: 62
# ####################
# ####################
# time point: 63
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 11017.9
# ####################
# time point: 64
# ####################
# ####################
# time point: 65
# ####################
# ####################
# time point: 66
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 10687.2
# ####################
# time point: 67
# ####################
# ####################
# time point: 68
# ####################
# ####################
# time point: 69
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 11244.7
# ####################
# time point: 70
# ####################
# ####################
# time point: 71
# ####################
# ####################
# time point: 72
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 11370.4
# ####################
# time point: 73
# ####################
# ####################
# time point: 74
# ####################
# ####################
# time point: 75
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 11753.7
# ####################
# time point: 76
# ####################
# ####################
# time point: 77
# ####################
# ####################
# time point: 78
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 11740.8
# ####################
# time point: 79
# ####################
# ####################
# time point: 80
# ####################
# ####################
# time point: 81
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 11451.9
# ####################
# time point: 82
# ####################
# ####################
# time point: 83
# ####################
# ####################
# time point: 84
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 12038
# ####################
# time point: 85
# ####################
# ####################
# time point: 86
# ####################
# ####################
# time point: 87
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 11939.8
# ####################
# time point: 88
# ####################
# ####################
# time point: 89
# ####################
# ####################
# time point: 90
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 12117.9
# ####################
# time point: 91
# ####################
# ####################
# time point: 92
# ####################
# ####################
# time point: 93
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 12148.6
# ####################
# time point: 94
# ####################
# ####################
# time point: 95
# ####################
# ####################
# time point: 96
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 12592.4
# ####################
# time point: 97
# ####################
# ####################
# time point: 98
# ####################
# ####################
# time point: 99
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 13553.8
# ####################
# time point: 100
# ####################
# ####################
# time point: 101
# ####################
# ####################
# time point: 102
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 13662.3
# ####################
# time point: 103
# ####################
# ####################
# time point: 104
# ####################
# ####################
# time point: 105
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 14521.4
# ####################
# time point: 106
# ####################
# ####################
# time point: 107
# ####################
# ####################
# time point: 108
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 15046.4
# ####################
# time point: 109
# ####################
# ####################
# time point: 110
# ####################
# ####################
# time point: 111
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 14269.8
# ####################
# time point: 112
# ####################
# ####################
# time point: 113
# ####################
# ####################
# time point: 114
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 14620.1
# ####################
# time point: 115
# ####################
# ####################
# time point: 116
# ####################
# ####################
# time point: 117
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 15102.5
# ####################
# time point: 118
# ####################
# ####################
# time point: 119
# ####################
# ####################
# time point: 120
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 14736.5
# ####################
# time point: 121
# ####################
# ####################
# time point: 122
# ####################
# ####################
# time point: 123
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 14942.8
# ####################
# time point: 124
# ####################
# ####################
# time point: 125
# ####################
# ####################
# time point: 126
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 15157.6
# ####################
# time point: 127
# ####################
# ####################
# time point: 128
# ####################
# ####################
# time point: 129
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 15653.2
# ####################
# time point: 130
# ####################
# ####################
# time point: 131
# ####################
# ####################
# time point: 132
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 15822.7
# ####################
# time point: 133
# ####################
# ####################
# time point: 134
# ####################
# ####################
# time point: 135
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 15233.9
# ####################
# time point: 136
# ####################
# ####################
# time point: 137
# ####################
# ####################
# time point: 138
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 15431.8
# ####################
# time point: 139
# ####################
# ####################
# time point: 140
# ####################
# ####################
# time point: 141
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 15854.5
# ####################
# time point: 142
# ####################
# ####################
# time point: 143
# ####################
# ####################
# time point: 144
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 16308.9
# ####################
# time point: 145
# ####################
# ####################
# time point: 146
# ####################
# ####################
# time point: 147
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 16995.2
# ####################
# time point: 148
# ####################
# ####################
# time point: 149
# ####################
# ####################
# time point: 150
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 16880.4
# ####################
# time point: 151
# ####################
# ####################
# time point: 152
# ####################
# ####################
# time point: 153
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 17236.9
# ####################
# time point: 154
# ####################
# ####################
# time point: 155
# ####################
# ####################
# time point: 156
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 16292.9
# ####################
# time point: 157
# ####################
# ####################
# time point: 158
# ####################
# ####################
# time point: 159
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 17288.3
# ####################
# time point: 160
# ####################
# ####################
# time point: 161
# ####################
# ####################
# time point: 162
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 18156.7
# ####################
# time point: 163
# ####################
# ####################
# time point: 164
# ####################
# ####################
# time point: 165
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 18091
# ####################
# time point: 166
# ####################
# ####################
# time point: 167
# ####################
# ####################
# time point: 168
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 18002.2
# ####################
# time point: 169
# ####################
# ####################
# time point: 170
# ####################
# ####################
# time point: 171
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 18469.9
# ####################
# time point: 172
# ####################
# ####################
# time point: 173
# ####################
# ####################
# time point: 174
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 19149.4
# ####################
# time point: 175
# ####################
# ####################
# time point: 176
# ####################
# ####################
# time point: 177
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 19485
# ####################
# time point: 178
# ####################
# ####################
# time point: 179
# ####################
# ####################
# time point: 180
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 19143.9
# ####################
# time point: 181
# ####################
# ####################
# time point: 182
# ####################
# ####################
# time point: 183
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 19676
# ####################
# time point: 184
# ####################
# ####################
# time point: 185
# ####################
# ####################
# time point: 186
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 19913.9
# ####################
# time point: 187
# ####################
# ####################
# time point: 188
# ####################
# ####################
# time point: 189
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 19474
# ####################
# time point: 190
# ####################
# ####################
# time point: 191
# ####################
# ####################
# time point: 192
# ####################
# Add vertices to graph
# Add sink and source vertex to graph
# Set up constraints
# Add Equations
# Optimize
# Optimal objective: 19536
# untangle
# detangling - set up equations
# detangling - solve optim problem
# Using license file /opt/gurobi/gurobi.lic
# Set parameter TokenServer to value matlablic.ohsu.edu
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (linux64)
# Thread count: 28 physical cores, 28 logical processors, using up to 28 threads
# Optimize a model with 55838 rows, 38312 columns and 182915 nonzeros
# Model fingerprint: 0x4eab84d8
# Variable types: 0 continuous, 38312 integer (26934 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+05]
#   Objective range  [1e+00, 2e+02]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 9e+00]
# Found heuristic solution: objective 25453.000000
# Presolve removed 21585 rows and 1410 columns
# Presolve time: 0.30s
# Presolved: 34253 rows, 36902 columns, 116639 nonzeros
# Found heuristic solution: objective 21417.000000
# Variable types: 0 continuous, 36902 integer (26043 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
# Concurrent spin time: 0.00s
#
# Solved with dual simplex
#
# Root relaxation: objective 1.448891e+04, 4593 iterations, 0.17 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 14488.9129    0 1511 21417.0000 14488.9129  32.3%     -    0s
# H    0     0                    15747.000000 14488.9129  7.99%     -    0s
# H    0     0                    15746.000000 14488.9129  7.98%     -    1s
# H    0     0                    15743.000000 14493.0962  7.94%     -    1s
#      0     0 15623.1702    0  192 15743.0000 15623.1702  0.76%     -    2s
# H    0     0                    15723.000000 15623.1702  0.63%     -    2s
# H    0     0                    15722.000000 15623.1702  0.63%     -    2s
#      0     0 15706.5612    0   48 15722.0000 15706.5612  0.10%     -    2s
#      0     0 15706.5612    0   36 15722.0000 15706.5612  0.10%     -    2s
# H    0     0                    15716.000000 15706.5612  0.06%     -    3s
#      0     0 15712.7936    0    6 15716.0000 15712.7936  0.02%     -    3s
#      0     0 infeasible    0      15716.0000 15716.0000  0.00%     -    5s
#
# Explored 1 nodes (6825 simplex iterations) in 5.12 seconds
# Thread count was 28 (of 28 available processors)
#
# Solution count 9: 15716 15716 15722 ... 25453
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.571600000000e+04, best bound 1.571600000000e+04, gap 0.0000%
# Optimal objective: 15716
# {'s_295': 2, 's_264': 1, 's_263': 1, 'e_6_291': 1, 'm_7_10': 1, 's_525': 1, 's_126': 1, 's_558': 1, 's_694': 1, 'm_233_234': 1, 'm_198_199': 1, 'e_21_245': 1, 'm_460_461': 1, 'm_27_31': 1, 'm_130_131': 1, 'm_250_251': 1, 's_225': 1, 's_370': 1, 'e_38_472': 1, 's_563': 1, 'm_134_135': 1, 's_154': 1, 'm_51_54': 1, 'm_205_206': 1, 's_1072': 1, 'e_58_266': 1, 'm_241_243': 1, 'm_286_287': 1, 'e_63_371': 1, 'm_64_65': 1, 'm_66_67': 1, 'm_382_383': 1, 's_744': 1, 'm_3597_3598': 1, 's_740': 1, 's_373': 1, 'm_1019_1035': 1, 'e_86_155': 1, 's_221': 1, 's_4724': 1, 'm_6197_6198': 1, 's_248': 1, 'e_95_247': 1, 'm_96_100': 1, 'm_140_141': 1, 'e_99_879': 1, 's_227': 1, 'm_258_259': 1, 's_1178': 1, 's_1793': 1, 'm_168_169': 1, 's_125': 1, 'm_201_202': 1, 'e_118_298': 1, 'm_177_178': 1, 's_179': 1, 's_422': 1, 'm_466_467': 1, 'e_132_881': 1, 's_881': 1, 'm_209_210': 1, 'm_166_167': 1, 'e_144_156': 1, 'm_218_220': 1, 'e_149_151': 1, 'e_151_297': 1, 'e_152_738': 1, 'm_242_244': 1, 'e_159_394': 1, 'e_161_228': 1, 's_182': 1, 's_185': 1, 'e_174_781': 1, 'm_265_398': 1, 's_271': 1, 'm_322_323': 1, 's_222': 1, 'm_276_277': 1, 'e_191_249': 1, 's_336': 1, 's_294': 1, 'm_280_281': 1, 's_392': 1, 'e_207_230': 1, 'm_358_359': 1, 'e_215_338': 1, 'e_217_288': 1, 'e_219_268': 1, 'e_224_395': 1, 'e_232_267': 1, 'e_238_456': 1, 's_335': 1, 'm_722_723': 1, 'e_249_428': 1, 's_262': 1, 'm_407_408': 1, 's_290': 1, 'm_671_672': 1, 'e_267_424': 1, 's_523': 1, 'm_970_971': 1, 'e_273_449': 1, 'm_449_481': 1, 's_337': 1, 's_393': 1, 'm_904_905': 1, 'e_285_986': 1, 's_367': 2, 'm_797_798': 1, 's_701': 1, 's_960': 1, 'm_356_357': 1, 'm_495_496': 1, 's_391': 1, 'e_311_369': 1, 's_659': 1, 'e_316_421': 1, 'm_342_343': 1, 'e_320_1350': 1, 'm_864_865': 1, 'e_324_377': 1, 'e_327_665': 1, 'e_329_566': 1, 's_390': 1, 'e_333_1032': 1, 'e_340_368': 1, 'e_347_374': 1, 'm_502_503_504': 1, 's_427': 1, 's_366': 1, 's_423': 1, 's_447': 1, 'e_361_1203': 1, 'e_362_564': 1, 'm_891_892': 1, 'e_368_478': 1, 'm_505_506': 1, 'e_532_955': 1, 's_429': 1, 'm_439_440': 1, 'e_385_420': 1, 'e_387_479': 1, 's_1073': 1, 'e_395_1360': 1, 's_425': 1, 'e_400_473': 1, 's_527': 1, 'e_402_450': 1, 'e_403_419': 1, 's_818': 1, 's_1137': 1, 's_448': 1, 's_953': 1, 's_1242': 1, 's_453': 1, 'e_424_1028': 1, 's_455': 2, 'm_464_465': 1, 'e_432_447': 1, 's_452': 1, 's_454': 1, 'e_445_623': 1, 'm_607_608': 1, 'm_806_812': 1, 'e_458_520': 1, 'm_510_511': 1, 'e_469_476': 1, 's_1170': 1, 's_593': 1, 's_592': 1, 'm_1339_1340': 1, 'm_546_547': 1, 's_526': 1, 'e_491_529': 1, 'e_499_779': 1, 'm_615_616': 1, 'e_514_565': 1, 'e_515_699': 1, 'e_517_522': 1, 'm_801_802': 1, 'm_759_760': 1, 'm_799_800': 1, 'm_638_640': 1, 's_560': 1, 's_627': 1, 'e_534_561': 1, 's_624': 1, 'e_541_598': 1, 'm_580_581': 1, 'e_544_600': 1, 'm_653_654': 1, 's_625': 1, 'e_557_562': 1, 'e_559_956': 1, 's_594': 1, 's_629': 1, 'e_569_622': 1, 'e_571_599': 1, 'e_574_595': 1, 's_596': 2, 'e_585_621': 1, 's_601': 1, 'e_589_664': 1, 'm_643_645': 1, 's_878': 1, 'm_720_721': 1, 'e_609_1141': 1, 'e_611_691': 1, 'm_714_715': 1, 'm_900_901': 1, 's_626': 1, 'e_620_628': 1, 's_700': 1, 's_695': 1, 'e_623_835': 1, 'e_628_659': 1, 's_1527': 1, 's_662': 1, 'e_658_661': 1, 'm_681_682': 1, 'e_660_696': 1, 's_1071': 1, 'e_673_1142': 1, 'e_677_774': 1, 's_735': 1, 's_820': 1, 'm_1002_1003': 1, 'e_685_987': 1, 's_917': 1, 'e_690_692': 1, 'm_889_890': 1, 'e_693_737': 1, 'e_696_838': 1, 'm_787_788': 1, 'e_702_1025': 1, 'm_1873_1874': 1, 'e_707_734': 1, 'm_766_767': 1, 'e_710_834': 1, 'm_834_923': 1, 'e_711_741': 1, 'e_713_736': 1, 's_1105': 1, 's_954': 1, 's_743': 1, 's_880': 1, 's_824': 1, 's_871': 1, 'e_731_951': 1, 'e_732_739': 1, 's_2824': 1, 'm_1252_1253': 1, 's_836': 1, 'm_2958_2959': 1, 's_815': 1, 's_857': 1, 's_817': 1, 's_993': 1, 'e_752_915': 1, 'e_753_776': 1, 'e_756_777': 1, 's_823': 1, 's_1026': 1, 'm_795_796': 1, 'e_769_957': 1, 'e_770_816': 1, 'm_1723_1724': 1, 'e_777_916': 1, 'e_779_1068': 1, 's_912': 1, 'e_781_1319': 1, 's_2618': 1, 'e_784_873': 1, 'm ...
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# ...
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
# Long-step dual simplex will be used
#
# add dummy masks
# export masks
# returned value from command line tracking with KIT: 0

# %% [markdown]
# #### Identify cells
# Read in the tracking results
# res_track.txt - A text file representing an acyclic graph for the whole image sequence. Every line corresponds to a single track that is encoded by four numbers separated by a space:
# L B E P where
# L - a unique label of the track (label of markers, 16-bit positive value)
# B - a zero-based temporal index of the frame in which the track begins
# E - a zero-based temporal index of the frame in which the track ends
# P - label of the parent track (0 is used when no parent is defined)
#
#
# Filter the track objects keeping the parents and those with a minimum track length and save the results to tracks.csv
#
# Create a new file tracks.csv with the following columns:
# label - a unique label of the track (label of markers, 16-bit positive value)
# begins - a zero-based temporal index of the frame in which the track begins
# ends - a zero-based temporal index of the frame in which the track ends
# parent - label of the parent track (0 is used when no parent is defined)
# length - The number of frames that the cell is identified in
# plateID - Character string of the plate's ID such as AU02001
# well - Character string of the well such as A1
# field - Integer of the image field within the well

# %%
#set filter parameters
min_track_length = 3
#loop through the results from each segmented field
for subdir in subdirectories:
    field = re.findall("field_[1-9]",subdir)[0]
    res_filename = os.path.join(output_path,"tracking",well,field,"results","res_track.txt")
    res_flt_filename = res_filename.replace("res_track.txt","tracks.csv")
    tracks = pd.read_csv(res_filename, sep=" ", header=None)
    tracks.columns = ["label", "begins", "ends", "parent"]
    tracks['length'] = tracks.ends - tracks.begins + 1
    last_track = tracks.ends.max()
    #check if object is a parent
    tracks["is_parent"] = tracks['label'].isin(tracks['parent'])
    tracks['plateID'] = plateID
    tracks['well'] = well
    tracks['field'] = field.replace("field_","") #only filter if no tracks.csv file
    #If filtered results do not exist, read in the res_track.txt file for the current field
    if not os.path.exists(res_flt_filename):
        #Filter using the filter parameters
        #remove short tracks that are not parents and are not in the last frame
        tracks_flt = tracks.query('length >= @min_track_length or is_parent or ends > (@last_track-@min_track_length)')
        ##remove any track that appears after the first frame and doesn't have a parent
        #tracks_flt = tracks_flt.query('not (begins > 1 & parent == 0)')
        #write out the res_flt_track.txt file
        tracks_flt.to_csv(res_flt_filename,index=False)

# %% [markdown]
# #### Filter masks to only tracked cells
# Use the filtered tracks to remove masks for non-cell objects
# Save the filtered masks as individual image files in filtered_masks directory

# %%
#loop through the fields in the well
for subdir in subdirectories:
    field = re.findall("field_[1-9]",subdir)[0]
    mask_track_path = os.path.join(output_path,"tracking",well,field,"results")
    tracked_mask_filenames = sorted(glob.glob(mask_track_path+"/mask*"))
    #condition on whether the filtered masks exist
    if not os.path.exists(tracked_mask_filenames[0].replace("results","cyto_filtered_masks")):
       #read in the tracks file for this field    
        res_flt_filename = os.path.join(output_path,"tracking",well,field,"results","tracks.csv")
        tracks = pd.read_csv(res_flt_filename) 
        #loop through the cyto mask images in the field
        for fn in tracked_mask_filenames:
            #read in the cyto mask image
            im_cyto = io.imread(fn)
            #read in the nuclear mask image
            im_nuc = io.imread(fn.replace("results","nuc_masks"))
           #replace any label that's not a cell with a 0 value
            cell_labels = np.array([x if x in tracks.label.to_numpy()
                                       else 0 for x in range(0, im_cyto.max()+1)])
            im_cyto_filtered = cell_labels[im_cyto]
            #replace any label that's not a cell with a 0 value
            nuc_labels = np.array([x if x in tracks.label.to_numpy()
                                       else 0 for x in range(0, im_nuc.max()+1)])
            im_nuc_filtered = nuc_labels[im_nuc]
            io.imsave(fn.replace("results","cyto_filtered_masks"), im_cyto_filtered.astype(np.int16), plugin='tifffile', check_contrast=False)
            io.imsave(fn.replace("results","nuc_filtered_masks"), im_nuc_filtered.astype(np.int16), plugin='tifffile', check_contrast=False)

# %% [markdown]
# #### Get excel metadata file
# If this file does not exists, cretae a level 0 file that is data only

# %%
#If the metadata exists, load it
metadata_filename = os.path.join(data_path,plateID,"metadata",plateID+".xlsx")

if os.path.exists(metadata_filename):
    md_all = pd.read_excel(metadata_filename, engine='openpyxl', dtype={'Drug1Concentration': str, 'Drug2Concentration': str})
    
    #remove unwanted columns read in from the excel files
    r = re.compile("Unnamed.*")
    columns_to_drop = list(filter(r.match, md_all.columns)) 
    metadata = md_all.drop(columns = columns_to_drop)
    
    #match metadata and data well labels format
    metadata['row'] = [re.sub(r'[0-9]*', '', Well) for Well in metadata['Well']]
    metadata['column'] = [re.sub(r'[A-Z]', '', Well) for Well in metadata['Well']]
    metadata['column'] = [re.sub(r'\A0', '', row) for row in metadata['column']]
    metadata['well'] = metadata['row'] + metadata['column']

# %% [markdown]
# #### Pull data from images
# Apply the filtered masks to the registered red nuclear channel and recored each cells nuclear morphology, intensity and texture
# Create cytoplasm masks by expanding the nuclear masks by a fixed amount or until they collide with another nuclear expansion
# Use the nuclear and cytoplasmic masks to measure intensities in the green fluroescent images
# Calculate intensity ratios between the cytomplasm and nuclei
# If the metadata is available, merge it with the cell level data
# Store the cell level data (and metadata) in a csv file where each row is a cell
# Data feature values can be decoded as follows:
# \<compartment>\_\<pipeline name>\_\<channel name>\_\<regionprops name>
# compartment - Nuclei, Cyto or Cell
# pipeline name - PC for python cellpose or other if added
# channel name - NR for nuclear reporter, CC for cell cycle reporter or others if added
# regionprops name - label passed through from the skimage measure.regionprops function https://scikit-image.org/docs/dev/api/skimage.measure.html#skimage.measure.regionprops

# %%
minutes_between_images = 30
neighborhood_nuclei_distance = 5
neighborhood_radius_near = 20
neighborhood_radius_medium = 45
neighborhood_radius_far = 70

#loop through the fields in the well
for subdir in subdirectories:
    field = re.findall("field_[1-9]",subdir)[0]
    l0_filename = os.path.join(data_path+plateID,"Analysis",pipeline_name,plateID+"_"+well+"_"+field+"_level_0.csv")

    #condition on whether the l1 and l2 files exist
    if not os.path.exists(l0_filename.replace('level_0','level_1'))&os.path.exists(l0_filename.replace('level_0','level_2')):
        print("Pulling data from images "+l0_filename.replace('_level_0.csv',''))
        cyto_filtered_mask_path = os.path.join(output_path,"tracking",well,field,"cyto_filtered_masks")
        nuc_filtered_mask_path = os.path.join(output_path,"tracking",well,field,"nuc_filtered_masks")
        cyto_tracked_mask_filenames = sorted(glob.glob(cyto_filtered_mask_path+"/mask*"))
        img_gs_reg = io.imread(os.path.join(registered_stacks_path,plateID+"_G_"+well+"_"+field.replace("field_","")+"_reg_stack.tif"))
        # iterate over the mask files
        results = []
        for i, fn in enumerate(cyto_tracked_mask_filenames):
            #read in the cyto mask image
            cyto_masks = io.imread(fn)
            #read in the nuclear mask image
            nuc_masks = io.imread(fn.replace("cyto_","nuc_"))
            #read in registered cell cycle images
            #reg_fn = fn.replace("filtered_masks","reg") #registered phase
            image = img_gs_reg[i]

            #measure cell cycle reporter intensity and nuclear morphology, texture
            cyto = measure.regionprops_table(cyto_masks, intensity_image=image,
                                               properties=('label',
                                                           'area','bbox_area','convex_area','centroid','eccentricity','equivalent_diameter','extent','feret_diameter_max','filled_area',
                                                            'major_axis_length','minor_axis_length','moments_hu','perimeter','perimeter_crofton','solidity',
                                                            'mean_intensity','max_intensity','min_intensity'))
            nuc = measure.regionprops_table(nuc_masks, intensity_image=image,
                                   properties=('label',
                                               'area','bbox_area','convex_area','centroid','eccentricity','equivalent_diameter','extent','feret_diameter_max','filled_area',
                                                'major_axis_length','minor_axis_length','moments_hu','perimeter','perimeter_crofton','solidity',
                                                'mean_intensity','max_intensity','min_intensity'))

            # turn results into a dataframe
            cyto_data = pd.DataFrame(cyto)
            cyto_data.rename(columns={col: 'Cyto_'+pipeline_name+'_' +ch2_name+'_'+col  for col in cyto_data.columns if col not in ['label']}, inplace=True)

            nuc_data = pd.DataFrame(nuc)
            nuc_data.rename(columns={col: 'Nuclei_'+pipeline_name+'_' +ch2_name+'_'+col  for col in nuc_data.columns if col not in ['label']}, inplace=True)


            # recover the well and field values and add them to the dataframe
            well = re.findall('/[A-Z][0-9]+/',fn)[0]
            well = re.sub('/','', well)
            cyto_data['well'] = well
            field = re.findall('field_[0-9]+',fn)[0]
            field = int(re.sub('field_','', field))
            cyto_data['field'] = field
            cyto_data['slice'] = i
            cyto_data['elapsed_minutes'] = i*minutes_between_images #assumes time slice numbering starts at 1
            elapsed_minutes = i*minutes_between_images #assumes time slice numbering starts at 1
            day = np.floor(elapsed_minutes/(24*60)).astype(int)
            hour = np.floor((elapsed_minutes-day*(24*60))/60).astype(int)
            minute = np.floor(elapsed_minutes-day*(24*60)-hour*60).astype(int)
            day = str(day).zfill(2)
            hour = str(hour).zfill(2)
            minute = str(minute).zfill(2)
            cyto_data['time_slice'] = day+"d"+hour+"h"+minute+"m"

            #Calculate ratio of ch2 cyto to nuclei intensities
            cyto_data['Cell_'+pipeline_name+'_' +ch2_name+'_mean_intensity_ratio'] = cyto_data['Cyto_'+pipeline_name+'_' +ch2_name+'_mean_intensity']/nuc_data['Nuclei_'+pipeline_name+'_' +ch2_name+'_mean_intensity']
            cyto_data['Cell_'+pipeline_name+'_' +ch2_name+'_max_intensity_ratio'] = cyto_data['Cyto_'+pipeline_name+'_' +ch2_name+'_max_intensity']/nuc_data['Nuclei_'+pipeline_name+'_' +ch2_name+'_max_intensity']
            cyto_data['Cell_'+pipeline_name+'_' +ch2_name+'_min_intensity_ratio'] = cyto_data['Cyto_'+pipeline_name+'_' +ch2_name+'_min_intensity']/nuc_data['Nuclei_'+pipeline_name+'_' +ch2_name+'_min_intensity']


            #calculate the neighborhood density on the nuclei centroids ###TODO replace with a measure of cytoplasm
            nuc_kd = spatial.KDTree(nuc_data[['Nuclei_CKcn_CC_centroid-0','Nuclei_CKcn_CC_centroid-1']])
            nuc_data['neighborhood_'+str(neighborhood_radius_near)] = nuc_kd.query_ball_point(nuc_data[['Nuclei_CKcn_CC_centroid-0','Nuclei_CKcn_CC_centroid-1']],
                                                                                                    r = neighborhood_radius_near, return_sorted = True, return_length=True)
            nuc_data['neighborhood_'+str(neighborhood_radius_medium)] = nuc_kd.query_ball_point(nuc_data[['Nuclei_CKcn_CC_centroid-0','Nuclei_CKcn_CC_centroid-1']],
                                                                                                    r = neighborhood_radius_medium, return_sorted = True, return_length=True)
            nuc_data['neighborhood_'+str(neighborhood_radius_far)] = nuc_kd.query_ball_point(nuc_data[['Nuclei_CKcn_CC_centroid-0','Nuclei_CKcn_CC_centroid-1']],
                                                                                                    r = neighborhood_radius_far, return_sorted = True, return_length=True)
                        
            #merge the dataframes from the different channels
            df_all = pd.merge(cyto_data, nuc_data, how="inner", on=["label"])

            # append this image's dataframe to the results list
            results.append(df_all)

        #concatenate all of the results from all images in the field
        l0_image = pd.concat(results)

        #join with the tracking results to get lineage, parent, frame length values
        tracks_filename = os.path.join(output_path,"tracking",well,"field_"+str(field),"results/tracks.csv")
        tracks = pd.read_csv(tracks_filename)
        l0 = pd.merge(l0_image, tracks, how="left", on=["label", "well", "field"])
        
        if os.path.exists(metadata_filename):
            #merge data and metadata on well values
            l1= pd.merge(l0, metadata, how="left", on=["well"]).round(decimals=2)
            l1['treatment'] =  l1['Drug1']+'_'+l1['Drug1Concentration']+'_'+l1['Drug2']+'_'+l1['Drug2Concentration']
            #filter out first 9 slices
            l1 = l1[l1['slice'] > 9]
            print("Writing "+l0_filename.replace('level_0','level_1') + " to disk")
            l1.to_csv(l0_filename.replace('level_0','level_1'), index = False)
#             #summarize to image level
#             l2 = l1.groupby(['plateID','well','field', 'time_slice', 'elapsed_minutes','Drug1','Drug1Concentration', 'Drug2', 'Drug2Concentration', 'treatment', 'cell_cycle_state_threshold']).agg(
#                 n = ('plateID', 'size'),
#                 length=('length', 'mean'),
#                 Nuclei_CKn_CC_area=('Nuclei_CKn_CC_area', 'mean'),
#                 Nuclei_CKn_CC_mean_intensity=('Nuclei_CKn_CC_mean_intensity', 'mean'),
#                 Cyto_CKn_CC_mean_intensity=('Cyto_CKn_CC_mean_intensity', 'mean'),
#                 Cell_CKn_CC_mean_intensity_ratio=('Cell_CKn_CC_mean_intensity_ratio', 'mean'),
#                 Cell_CKn_CC_max_intensity_ratio=('Cell_CKn_CC_max_intensity_ratio', 'mean'),
#                 Cell_CKn_CC_min_intensity_ratio=('Cell_CKn_CC_min_intensity_ratio', 'mean'),
#                 G1_proportion =('cell_cycle_state', calc_G1_prop),
#                 neighborhood_20 = ('neighborhood_'+str(neighborhood_radius_near), 'mean'), #TODO figure out how to summarize with dynamic name
#                 neighborhood_45 = ('neighborhood_'+str(neighborhood_radius_medium), 'mean'),
#                 neighborhood_70 = ('neighborhood_'+str(neighborhood_radius_far), 'mean')
#             ).reset_index().round(decimals=2)
#             l2['cell_cycle_state_threshold'] = g1_threshold

#             print("Writing "+l0_filename.replace('level_0','level_2') + " to disk")
#             l2.to_csv(l0_filename.replace('level_0','level_2'), index = False)
        else:
            print("no metadata file for "+plateID+" so creating level 0 file")
            l0 = l0.round(decimals=2)
            l0.to_csv(l0_filename, index = False)
# Out:
# Pulling data from images /home/exacloud/gscratch/HeiserLab/images/HC00801/Analysis/CKcn/HC00801_A1_field_1
# Writing /home/exacloud/gscratch/HeiserLab/images/HC00801/Analysis/CKcn/HC00801_A1_field_1_level_1.csv to disk
# Pulling data from images /home/exacloud/gscratch/HeiserLab/images/HC00801/Analysis/CKcn/HC00801_A1_field_2
# Writing /home/exacloud/gscratch/HeiserLab/images/HC00801/Analysis/CKcn/HC00801_A1_field_2_level_1.csv to disk
# Pulling data from images /home/exacloud/gscratch/HeiserLab/images/HC00801/Analysis/CKcn/HC00801_A1_field_3
# Writing /home/exacloud/gscratch/HeiserLab/images/HC00801/Analysis/CKcn/HC00801_A1_field_3_level_1.csv to disk
# Pulling data from images /home/exacloud/gscratch/HeiserLab/images/HC00801/Analysis/CKcn/HC00801_A1_field_4
# Writing /home/exacloud/gscratch/HeiserLab/images/HC00801/Analysis/CKcn/HC00801_A1_field_4_level_1.csv to disk
